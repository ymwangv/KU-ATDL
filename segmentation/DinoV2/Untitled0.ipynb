# %%
import matplotlib.pyplot as plt

# 数据示例
epochs = list(range(1, 41))

# ConvNext数据
convnext_loss = [0.2459, 0.1299, 0.1004, 0.0874, 0.0725, 0.0395, 0.0285, 0.0220, 0.0183, 0.0164,
                 0.0137, 0.0123, 0.0122, 0.0111, 0.0105, 0.0097, 0.0101, 0.0094, 0.0088, 0.0081,
                 0.0075, 0.0072, 0.0077, 0.0077, 0.0069, 0.0067, 0.0068, 0.0068, 0.0067, 0.0062,
                 0.0058, 0.0058, 0.0058, 0.0059, 0.0058, 0.0061, 0.0059, 0.0054, 0.0058, 0.0048]
convnext_iou = [0.0000, 0.0000, 0.6147, 0.5940, 0.7694, 0.8101, 0.7836, 0.8128, 0.8160, 0.8214,
                0.8252, 0.8234, 0.8271, 0.8200, 0.8241, 0.8252, 0.8211, 0.8204, 0.8292, 0.8282,
                0.8276, 0.8305, 0.8274, 0.8270, 0.8293, 0.8282, 0.8289, 0.8273, 0.8277, 0.8275,
                0.8293, 0.8289, 0.8281, 0.8302, 0.8310, 0.8304, 0.8273, 0.8301, 0.8303, 0.8306]

# DinoV2数据
dinov2_loss = [0.3535, 0.2507, 0.2348, 0.2216, 0.2093, 0.1947, 0.1797, 0.1659, 0.1555, 0.1433,
               0.1355, 0.1271, 0.1195, 0.1132, 0.1058, 0.1015, 0.0928, 0.0894, 0.0844, 0.0801,
               0.0771, 0.0735, 0.0720, 0.0679, 0.0652, 0.0643, 0.0618, 0.0594, 0.0564, 0.0548,
               0.0550, 0.0521, 0.0520, 0.0507, 0.0485, 0.0475, 0.0472, 0.0466, 0.0477, 0.0454]
dinov2_iou = [0.0000, 0.0000, 0.0000, 0.0340, 0.0839, 0.1421, 0.2294, 0.2942, 0.3029, 0.3330,
              0.3476, 0.3513, 0.3694, 0.3585, 0.3457, 0.3532, 0.3387, 0.3479, 0.3847, 0.3619,
              0.3684, 0.3613, 0.3707, 0.3769, 0.3682, 0.3652, 0.3608, 0.3830, 0.3676, 0.3838,
              0.3810, 0.3826, 0.3815, 0.3764, 0.3819, 0.3747, 0.3755, 0.3698, 0.3807, 0.3774]

# 绘制训练损失曲线
plt.figure(figsize=(12, 6))

# 损失
plt.subplot(1, 2, 1)
plt.plot(epochs, convnext_loss, label="ConvNext Loss", color="orange", marker="o")
plt.plot(epochs, dinov2_loss, label="DinoV2 Loss", color="blue", marker="o")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.legend()
plt.grid()

# IoU
plt.subplot(1, 2, 2)
plt.plot(epochs, convnext_iou, label="ConvNext IoU", color="orange", marker="o")
plt.plot(epochs, dinov2_iou, label="DinoV2 IoU", color="blue", marker="o")
plt.xlabel("Epochs")
plt.ylabel("IoU")
plt.title("Validation IoU Over Epochs")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# 数据
epochs = list(range(1, 41))

# ConvNext 数据
convnext_loss = [
    0.2767, 0.1636, 0.0867, 0.0553, 0.0388, 0.0331, 0.0245, 0.0202, 0.0178, 0.0160,
    0.0145, 0.0139, 0.0132, 0.0117, 0.0107, 0.0101, 0.0101, 0.0095, 0.0088, 0.0086,
    0.0088, 0.0087, 0.0083, 0.0080, 0.0077, 0.0072, 0.0066, 0.0066, 0.0069, 0.0068,
    0.0063, 0.0062, 0.0065, 0.0069, 0.0066, 0.0059, 0.0060, 0.0060, 0.0058, 0.0056
]
convnext_iou = [
    0.5260, 0.6778, 0.7479, 0.7706, 0.7735, 0.8002, 0.7911, 0.7988, 0.8025, 0.7956,
    0.8004, 0.7961, 0.8004, 0.8002, 0.8015, 0.8009, 0.8007, 0.8026, 0.8033, 0.8011,
    0.7986, 0.8044, 0.8022, 0.8020, 0.8049, 0.8000, 0.8031, 0.7996, 0.8033, 0.7990,
    0.8014, 0.8022, 0.8018, 0.8007, 0.8018, 0.7995, 0.8010, 0.7998, 0.7985, 0.8006
]

# DinoV2 数据
dinov2_loss = [
    0.3993, 0.3372, 0.3213, 0.3062, 0.2952, 0.2855, 0.2713, 0.2576, 0.2502, 0.2400,
    0.2285, 0.2122, 0.2047, 0.1904, 0.1824, 0.1736, 0.1628, 0.1509, 0.1427, 0.1373,
    0.1303, 0.1203, 0.1161, 0.1119, 0.1073, 0.1019, 0.0979, 0.0916, 0.0912, 0.0918,
    0.0826, 0.0794, 0.0766, 0.0772, 0.0737, 0.0700, 0.0665, 0.0702, 0.0670, 0.0645
]
dinov2_iou = [
    0.0000, 0.0620, 0.1535, 0.2524, 0.2551, 0.3096, 0.3176, 0.3484, 0.3388, 0.3118,
    0.3774, 0.3672, 0.3752, 0.3471, 0.3604, 0.3746, 0.3504, 0.3562, 0.3489, 0.3532,
    0.3695, 0.3605, 0.3717, 0.3606, 0.3709, 0.3605, 0.3393, 0.3580, 0.3534, 0.3509,
    0.3631, 0.3635, 0.3489, 0.3594, 0.3478, 0.3500, 0.3360, 0.3528, 0.3525, 0.3623
]

# 绘制图像
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Loss 曲线
axes[0].plot(epochs, convnext_loss, label="ConvNext Loss", color="orange", marker="o")
axes[0].plot(epochs, dinov2_loss, label="DinoV2 Loss", color="blue", marker="o")
axes[0].set_title("Training Loss Over Epochs")
axes[0].set_xlabel("Epochs")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[0].grid()

# IoU 曲线
axes[1].plot(epochs, convnext_iou, label="ConvNext IoU", color="orange", marker="o")
axes[1].plot(epochs, dinov2_iou, label="DinoV2 IoU", color="blue", marker="o")
axes[1].set_title("Validation IoU Over Epochs")
axes[1].set_xlabel("Epochs")
axes[1].set_ylabel("IoU")
axes[1].legend()
axes[1].grid()

# 调整布局并显示
plt.tight_layout()
plt.show()
